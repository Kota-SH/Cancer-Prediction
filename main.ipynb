# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
def init_data():
    data_set=pd.read_csv("wdbc.csv",header=None)
    data_set.drop(0,axis=1,inplace=True)
    data_set[1].replace("B",0,inplace=True)
    data_set[1].replace("M",1,inplace=True)
    return data_set

# %%
#initializing the weights
def initialize(m):
#m is the no. of training examples    
    w = np.zeros((m,1))
    bias = 0
    
    return w , bias

# %%
#Sigmoid Fuction
def sigmoid(Z):
    return 1/(1 + np.exp(- Z))

# %%
#Calculating the Cost and gradients
def gradient(X, Y, weights, bias):
    
    m = X.shape[1] #Number of training examples
    #print(Y.shape)

    #calculating the cost, Forward Propagation
    Z = np.dot(weights.T, X) + bias;    
    a = sigmoid(Z)
    cost= -(1/m) * np.sum(Y * np.log(a) + (1-Y) * np.log(1-a))
        
    #calculating the gradients to minimize the cost function , Backward Propagation
    derived_weights = (1/m)* np.dot(X, (a-Y).T)
    derived_bias = (1/m)* np.sum(a-Y)
    
    #print('weights',dw.shape)
    
    gradients = {"dw" : derived_weights, "db" : derived_bias}
    
    return gradients, cost

# %%
def descent(X, Y, w, bias, epoch, learning_rate):
    
    costs=[]
    predictions=[]
    
    for i in range(epoch):
 
        gradients, cost = gradient(X, Y, w, bias)
        
        derived_weights = gradients["dw"]
        derived_bias = gradients["db"]
        
        w = w - learning_rate * derived_weights
        bias = bias - learning_rate * derived_bias
        
        #Storing the cost at interval of every 100 iterations
        if i % 10 == 0:
            costs.append(cost)
            print("cost after %i iteration : %f" % (i, cost))
        
        prediction = predictor(X, w, bias)
        predictions.append(100 - np.mean(np.abs(prediction - Y.T)) * 100)
        
            
    w = {"w":w, "b":bias}
    gradients = {"dw":derived_weights, "db":derived_bias}
    
    return w, gradients, costs, predictions

# %%
def predictor(X, w, bias):
    
    m = X.shape[1] #Number of training examples
    
    y_prediction =  np.zeros((1,m))
    
    w = w.reshape(X.shape[0], 1)
    
    a=sigmoid(np.dot(w.T, X)+bias)
    
    #print(sigmoid . round(0.5))
    
    for i in range(a.shape[1]):
        
        if(a[0,i]<0.5):
            y_prediction[0,i]=0
        else:
            y_prediction[0,i]=1           
    
    return y_prediction

# %%
def regression(Xtrain, Ytrain, epoch, learning_rate):
    
    no_of_dimensions = Xtrain.shape[0] #Number of features
    
    w,bias = initialize(no_of_dimensions)
    
    parameters, gradients, costs, predictions = descent(Xtrain, Ytrain, w, bias, epoch, learning_rate) 
    
    w = parameters["w"]
    bias = parameters["b"]
    
    d={"w":w, "b":bias, "costs": costs, "accuracy": predictions}
    
    return d

# %%
input_data=init_data()

#Splitting the data into train, test and validation sets
train_test , test= train_test_split(input_data , test_size = 0.1 , random_state = 45)
train , validate= train_test_split(train_test , test_size = (1/9) , random_state = 45)

#Assigning the columns to dependent and independent vectors. 
x_train = train.loc[:, 1:31]
y_train = train.loc[:, 1]
x_val   = validate.loc[:, 1:31]
y_val   = validate.loc[:, 1]
x_test  = test.loc[:, 1:31]
y_test  = test.loc[:, 1]

x_train = np.asarray(x_train)
y_train = np.asarray(y_train)
x_val   = np.asarray(x_val)
y_val   = np.asarray(y_val)
x_test  = np.asarray(x_test)
y_test  = np.asarray(y_test)


# Feature Scaling and Normalizing the data for optimum results
mean_train  = np.mean(x_train, axis = 0)
std_train   = np.std(x_train, axis = 0)
mean_val    = np.mean(x_val, axis = 0)
std_val     = np.std(x_val, axis = 0)
mean_test   = np.mean(x_test, axis = 0)
std_test    = np.std(x_test, axis = 0)

x_train = (x_train - mean_train) / std_train
x_val = (x_val - mean_val) / std_val
x_test = (x_test - mean_test) / std_test

# %%
regression_model = regression(x_val.T, y_val.T, epoch=2000,learning_rate = 0.002)

costs=regression_model["costs"]
w=regression_model["w"]
bias=regression_model["b"]
Accuracy=regression_model["accuracy"]
#print(costs)

#Drawing the plot between cost and number of iterations
plt.plot(costs)
plt.title("Cost vs Number of Iterations")
plt.xlabel("Number of Iterations ( * 10)")
plt.ylabel("Cost")
# Out:
# cost after 0 iteration : 0.693147
# cost after 10 iteration : 0.653039
# cost after 20 iteration : 0.617822
# cost after 30 iteration : 0.586814
# cost after 40 iteration : 0.559408
# cost after 50 iteration : 0.535080
# cost after 60 iteration : 0.513383
# cost after 70 iteration : 0.493939
# cost after 80 iteration : 0.476431
# cost after 90 iteration : 0.460594
# cost after 100 iteration : 0.446204
# cost after 110 iteration : 0.433073
# cost after 120 iteration : 0.421042
# cost after 130 iteration : 0.409978
# cost after 140 iteration : 0.399767
# cost after 150 iteration : 0.390311
# cost after 160 iteration : 0.381527
# cost after 170 iteration : 0.373342
# cost after 180 iteration : 0.365695
# cost after 190 iteration : 0.358531
# cost after 200 iteration : 0.351803
# cost after 210 iteration : 0.345470
# cost after 220 iteration : 0.339495
# cost after 230 iteration : 0.333847
# cost after 240 iteration : 0.328498
# cost after 250 iteration : 0.323422
# cost after 260 iteration : 0.318596
# cost after 270 iteration : 0.314001
# cost after 280 iteration : 0.309619
# cost after 290 iteration : 0.305434
# cost after 300 iteration : 0.301431
# cost after 310 iteration : 0.297597
# cost after 320 iteration : 0.293921
# cost after 330 iteration : 0.290391
# cost after 340 iteration : 0.286998
# cost after 350 iteration : 0.283732
# cost after 360 iteration : 0.280586
# cost after 370 iteration : 0.277553
# cost after 380 iteration : 0.274625
# cost after 390 iteration : 0.271796
# cost after 400 iteration : 0.269060
# cost after 410 iteration : 0.266413
# cost after 420 iteration : 0.263848
# cost after 430 iteration : 0.261362
# cost after 440 iteration : 0.258951
# cost after 450 iteration : 0.256610
# cost after 460 iteration : 0.254336
# cost after 470 iteration : 0.252125
# cost after 480 iteration : 0.249975
# cost after 490 iteration : 0.247882
# cost after 500 iteration : 0.245844
# cost after 510 iteration : 0.243858
# cost after 520 iteration : 0.241922
# cost after 530 iteration : 0.240033
# cost after 540 iteration : 0.238190
# cost after 550 iteration : 0.236391
# cost after 560 iteration : 0.234632
# cost after 570 iteration : 0.232914
# cost after 580 iteration : 0.231234
# cost after 590 iteration : 0.229591
# cost after 600 iteration : 0.227983
# cost after 610 iteration : 0.226409
# cost after 620 iteration : 0.224867
# cost after 630 iteration : 0.223357
# cost after 640 iteration : 0.221877
# cost after 650 iteration : 0.220426
# cost after 660 iteration : 0.219002
# cost after 670 iteration : 0.217606
# cost after 680 iteration : 0.216236
# cost after 690 iteration : 0.214891
# cost after 700 iteration : 0.213571
# cost after 710 iteration : 0.212274
# cost after 720 iteration : 0.211000
# cost after 730 iteration : 0.209747
# cost after 740 iteration : 0.208516
# cost after 750 iteration : 0.207306
# cost after 760 iteration : 0.206116
# cost after 770 iteration : 0.204945
# cost after 780 iteration : 0.203792
# cost after 790 iteration : 0.202658
# cost after 800 iteration : 0.201542
# cost after 810 iteration : 0.200443
# cost after 820 iteration : 0.199360
# cost after 830 iteration : 0.198294
# cost after 840 iteration : 0.197244
# cost after 850 iteration : 0.196208
# cost after 860 iteration : 0.195188
# cost after 870 iteration : 0.194182
# cost after 880 iteration : 0.193191
# cost after 890 iteration : 0.192213
# cost after 900 iteration : 0.191248
# cost after 910 iteration : 0.190297
# cost after 920 iteration : 0.189358
# cost after 930 iteration : 0.188432
# cost after 940 iteration : 0.187518
# cost after 950 iteration : 0.186615
# cost after 960 iteration : 0.185724
# cost after 970 iteration : 0.184845
# cost after 980 iteration : 0.183976
# cost after 990 iteration : 0.183118
# cost after 1000 iteration : 0.182271
# cost after 1010 iteration : 0.181434
# cost after 1020 iteration : 0.180607
# cost after 1030 iteration : 0.179789
# cost after 1040 iteration : 0.178982
# cost after 1050 iteration : 0.178183
# cost after 1060 iteration : 0.177394
# cost after 1070 iteration : 0.176614
# cost after 1080 iteration : 0.175843
# cost after 1090 iteration : 0.175080
# cost after 1100 iteration : 0.174325
# cost after 1110 iteration : 0.173579
# cost after 1120 iteration : 0.172841
# cost after 1130 iteration : 0.172111
# cost after 1140 iteration : 0.171389
# cost after 1150 iteration : 0.170674
# cost after 1160 iteration : 0.169967
# cost after 1170 iteration : 0.169267
# cost after 1180 iteration : 0.168574
# cost after 1190 iteration : 0.167888
# cost after 1200 iteration : 0.167209
# cost after 1210 iteration : 0.166537
# cost after 1220 iteration : 0.165872
# cost after 1230 iteration : 0.165213
# cost after 1240 iteration : 0.164561
# cost after 1250 iteration : 0.163915
# cost after 1260 iteration : 0.163275
# cost after 1270 iteration : 0.162641
# cost after 1280 iteration : 0.162013
# cost after 1290 iteration : 0.161391
# cost after 1300 iteration : 0.160775
# cost after 1310 iteration : 0.160165
# cost after 1320 iteration : 0.159560
# cost after 1330 iteration : 0.158960
# cost after 1340 iteration : 0.158366
# cost after 1350 iteration : 0.157778
# cost after 1360 iteration : 0.157194
# cost after 1370 iteration : 0.156616
# cost after 1380 iteration : 0.156043
# cost after 1390 iteration : 0.155475
# cost after 1400 iteration : 0.154911
# cost after 1410 iteration : 0.154353
# cost after 1420 iteration : 0.153799
# cost after 1430 iteration : 0.153250
# cost after 1440 iteration : 0.152706
# cost after 1450 iteration : 0.152166
# cost after 1460 iteration : 0.151630
# cost after 1470 iteration : 0.151099
# cost after 1480 iteration : 0.150573
# cost after 1490 iteration : 0.150050
# cost after 1500 iteration : 0.149532
# cost after 1510 iteration : 0.149018
# cost after 1520 iteration : 0.148508
# cost after 1530 iteration : 0.148002
# cost after 1540 iteration : 0.147501
# cost after 1550 iteration : 0.147003
# cost after 1560 iteration : 0.146508
# cost after 1570 iteration : 0.146018
# cost after 1580 iteration : 0.145532
# cost after 1590 iteration : 0.145049
# cost after 1600 iteration : 0.144570
# cost after 1610 iteration : 0.144094
# cost after 1620 iteration : 0.143622
# cost after 1630 iteration : 0.143154
# cost after 1640 iteration : 0.142689
# cost after 1650 iteration : 0.142227
# cost after 1660 iteration : 0.141769
# cost after 1670 iteration : 0.141315
# cost after 1680 iteration : 0.140863
# cost after 1690 iteration : 0.140415
# cost after 1700 iteration : 0.139970
# cost after 1710 iteration : 0.139528
# cost after 1720 iteration : 0.139089
# cost after 1730 iteration : 0.138654
# cost after 1740 iteration : 0.138221
# cost after 1750 iteration : 0.137792
# cost after 1760 iteration : 0.137365
# cost after 1770 iteration : 0.136942
# cost after 1780 iteration : 0.136521
# cost after 1790 iteration : 0.136103
# cost after 1800 iteration : 0.135688
# cost after 1810 iteration : 0.135276
# cost after 1820 iteration : 0.134867
# cost after 1830 iteration : 0.134460
# cost after 1840 iteration : 0.134056
# cost after 1850 iteration : 0.133655
# cost after 1860 iteration : 0.133256
# cost after 1870 iteration : 0.132860
# cost after 1880 iteration : 0.132467
# cost after 1890 iteration : 0.132076
# cost after 1900 iteration : 0.131688
# cost after 1910 iteration : 0.131302
# cost after 1920 iteration : 0.130919
# cost after 1930 iteration : 0.130538
# cost after 1940 iteration : 0.130160
# cost after 1950 iteration : 0.129784
# cost after 1960 iteration : 0.129410
# cost after 1970 iteration : 0.129039
# cost after 1980 iteration : 0.128670
# cost after 1990 iteration : 0.128304
# Text(0,0.5,'Cost')

# %%
#Drawing the plot between cost and number of iterations
plt.plot(Accuracy)
#plt.title("Predtictions vs Number of Iterations")
##Drawing the plot between cost and number of iterations
#plt.plot(costs)
plt.title("Accuracy vs Number of Iterations")
plt.xlabel("Number of Iterations ( * 10)")
plt.ylabel("Accuracy")
# Out:
# Text(0,0.5,'Accuracy')

# %%
prediction_train = predictor(x_train.T, w, bias)
prediction_test = predictor(x_test.T, w, bias)
prediction_val = predict(x_val.T, weights,bias)

accuracy_n=0
accuracy_d=0
precision_n=0
precision_d=0
recall_n=0
recall_d=0

for i in range (x_test.shape[0]):
    x= str(prediction_test.T[i])
    if(str(y_test[i]) == x[1]):
        accuracy_n+=1
    accuracy_d+=1
    if(x[1] == '1'):
        precision_d+=1
        if(y_test[i] == 1):
            precision_n+=1
    
    if(y_test[i] == 1):
        recall_d+=1
        if(x[1] == '1'):
            recall_n+=1

accuracy = accuracy_n / accuracy_d *100
precision = precision_n / precision_d *100
recall = recall_n / recall_d *100
fmeasure = 2 * (recall *precision) / (recall + precision)

print('Test Data Accuracy: ', accuracy)
print('Precision: ', precision)
print('Recall: ', recall)
print('f_measure: ', fmeasure)
# Out:
# Test Data Accuracy:  91.22807017543859
# Precision:  78.94736842105263
# Recall:  93.75
# f_measure:  85.71428571428571
